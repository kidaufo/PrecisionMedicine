# %%
import pandas as pd
texts = pd.read_table("training_text", sep="\|\|", engine="python", squeeze=True)
texts.name = "Text"

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
vectorizer = CountVectorizer(min_df=1)

# %%
X = vectorizer.fit_transform([texts[0]])

# %%
vectorizer.get_feature_names()
# Out:
# ['000',
#  '001',
#  '01',
#  '068',
#  '10',
#  '100',
#  '1019',
#  '11',
#  '12',
#  '123_152',
#  '13',
#  '13362',
#  '14',
#  '15',
#  '152',
#  '16',
#  '1640',
#  '164_152',
#  '17',
#  '170窶',
#  '172窶',
#  '18',
#  '19',
#  '1a',
#  '1a窶塗',
#  '1b',
#  '1c',
#  '1d',
#  '1e',
#  '1f',
#  '1g',
#  '1i',
#  '1j',
#  '1mm',
#  '1窶',
#  '20',
#  '200',
#  '2000',
#  '201dupt',
#  '2033',
#  '21',
#  '214',
#  '22',
#  '220',
#  '225',
#  '23',
#  '231del',
#  '24',
#  '249',
#  '25',
#  '250',
#  '257',
#  '26',
#  '265',
#  '27',
#  '2a',
#  '2b',
#  '2窶',
#  '30',
#  '300',
#  '32',
#  '32p',
#  '340598',
#  '36',
#  '37',
#  '371del',
#  '3a',
#  '3窶',
#  '40',
#  '454',
#  '48',
#  '492',
#  '496943',
#  '4a',
#  '4b',
#  '4c',
#  '4d',
#  '4th',
#  '4窶',
#  '50',
#  '500',
#  '504',
#  '508',
#  '514',
#  '554',
#  '555',
#  '556',
#  '56',
#  '5a',
#  '5b',
#  '5c',
#  '5th',
#  '60',
#  '608',
#  '642',
#  '6516',
#  '6his',
#  '72',
#  '75',
#  '774',
#  '93',
#  '97',
#  '9窶',
#  'a5060',
#  'ab9106',
#  'abcam',
#  'aberrant',
#  'ability',
#  'abnormalities',
#  'abolishes',
#  'above',
#  'absence',
#  'acceptor',
#  'accordance',
#  'according',
#  'achieved',
#  'acid',
#  'acids',
#  'act',
#  'actin',
#  'action',
#  'activate',
#  'activated',
#  'activates',
#  'activating',
#  'activation',
#  'activator',
#  'active',
#  'activity',
#  'added',
#  'additional',
#  'address',
#  'adult',
#  'affected',
#  'affecting',
#  'affinity',
#  'after',
#  'agarose',
#  'ago',
#  'aim',
#  'alanine',
#  'albeit',
#  'all',
#  'allele',
#  'allow',
#  'almost',
#  'alone',
#  'already',
#  'also',
#  'alter',
#  'alternative',
#  'alters',
#  'although',
#  'altogether',
#  'amino',
#  'among',
#  'amounts',
#  'amplicon',
#  'amplicons',
#  'an',
#  'anal',
#  'analysis',
#  'analyzed',
#  'analyzing',
#  'and',
#  'anogenital',
#  'anomalies',
#  'anomaly',
#  'another',
#  'anti',
#  'antibodies',
#  'antibody',
#  'any',
#  'apc',
#  'apparent',
#  'appearance',
#  'appearances',
#  'approximately',
#  'are',
#  'arising',
#  'array',
#  'arrow',
#  'as',
#  'ascertainment',
#  'assay',
#  'assayed',
#  'assays',
#  'associated',
#  'at',
#  'atp',
#  'atp2b3',
#  'atresia',
#  'attributable',
#  'atypical',
#  'authors',
#  'autonomous',
#  'autoradiography',
#  'autosomal',
#  'available',
#  'a窶吐',
#  'a窶鼎',
#  'b42',
#  'bac',
#  'bacmids',
#  'baculoviruses',
#  'bait',
#  'baits',
#  'band',
#  'bar',
#  'bars',
#  'basis',
#  'be',
#  'bead',
#  'beads',
#  'bearing',
#  'because',
#  'been',
#  'belong',
#  'below',
#  'between',
#  'bias',
#  'binding',
#  'bio',
#  'biological',
#  'biotechnology',
#  'birth',
#  'bis',
#  'black',
#  'blot',
#  'blots',
#  'blotting',
#  'blue',
#  'body',
#  'bona',
#  'both',
#  'bottom',
#  'box',
#  'boxes',
#  'boys',
#  'bp',
#  'bradford',
#  'brain',
#  'breakpoint',
#  'breast',
#  'bring',
#  'broad',
#  'broader',
#  'brocks',
#  'bsa',
#  'buffer',
#  'build',
#  'but',
#  'by',
#  'called',
#  'can',
#  'cancer',
#  'cancers',
#  'cannot',
#  'capture',
#  'cardinal',
#  'carried',
#  'carrying',
#  'case',
#  'cases',
#  'cause',
#  'caused',
#  'causing',
#  'ccnd1',
#  'cdh1',
#  'cdh1窶杜ediated',
#  'cdi1',
#  'cdk',
#  'cdk1',
#  'cdk10',
#  'cdk10kd',
#  'cdk11',
#  'cdk3',
#  'cdk7',
#  'cdk8',
#  'cdks',
#  'cdnas',
#  'cell',
#  'cells',
#  'cellular',
#  'centrifugation',
#  'centromeric',
#  'certain',
#  'cervix',
#  'cgh',
#  'changes',
#  'characteristic',
#  'characterization',
#  'chemiluminescence',
#  'child',
#  'chimpanzee',
#  'chromosome',
#  'chromosomes',
#  'cip1',
#  'clinical',
#  'clinically',
#  'cloning',
#  'closest',
#  'cnv',
#  'co',
#  'cobalt',
#  'coding',
#  'codon',
#  'coexpressed',
#  'coexpressing',
#  'coexpression',
#  'cognate',
#  'coimmunoprecipitation',
#  'coinfected',
#  'coktail',
#  'coli',
#  'collected',
#  'coloboma',
#  'colocalizes',
#  'colon',
#  'combination',
#  'combinations',
#  'combined',
#  'comigrates',
#  'comparative',
#  'compare',
#  'compared',
#  'complete',
#  'complex',
#  'complexed',
#  'compromised',
#  'concentration',
#  'concerted',
#  'condition',
#  'conferring',
#  'confers',
#  'confirm',
#  'confirmed',
#  'confirming',
#  'conform',
#  'consent',
#  'consequence',
#  'conserved',
#  'considerably',
#  'considered',
#  'consists',
#  'constraints',
#  'constructions',
#  'containing',
#  'contains',
#  'content',
#  'context',
#  'contrary',
#  'contribute',
#  'control',
#  'controls',
#  'coomassie',
#  'cooperatively',
#  'copies',
#  'copurified',
#  'copy',
#  'correspond',
#  'corresponding',
#  'corresponds',
#  'cotransfected',
#  'could',
#  'coupled',
#  'covalab',
#  'cranial',
#  'crl4',
#  'cruz',
#  'cullin',
#  'cultures',
#  'customized',
#  'cut',
#  'cycle',
#  'cyclin',
#  'cyclins',
#  'cycm',
#  'cycm窶菟roducing',
#  'd1',
#  'd181a',
#  'd2',
#  'data',
#  'databases',
#  'date13',
#  'daughter',
#  'de',
#  'de3',
#  'dead',
#  'decay',
#  'decrease',
#  'decreased',
#  'defect',
#  'define',
#  'defined',
#  'degeneration',
#  'degradation',
#  'degraded',
#  'deleterious',
#  'deletion',
#  'deletions',
#  'delta',
#  'demonstrate',
#  'demonstrated',
#  'demonstrating',
#  'denatured',
#  'deorphanize',
#  'dependent',
#  'deregulated',
#  'derepresses',
#  'derived',
#  'described',
#  'destruction',
#  'detailed',
#  'detect',
#  'detectable',
#  'detected',
#  'detecting',
#  'determine',
#  'determined',
#  'develop',
#  'development',
#  'developmental',
#  'dh10bac',
#  'diagnosed',
#  'did',
#  'differ',
#  'different',
#  'differing',
#  'dilution',
#  'direct',
#  'directed',
#  'directing',
#  'directly',
#  'disadvantage',
#  'discovered',
#  'disease',
#  'disruptor',
#  'division',
#  'dmem',
#  'dna',
#  'do',
#  'docking',
#  'does',
#  'dog',
#  'domain',
#  'dominant',
#  'donor',
#  'dosage',
#  'doublet',
#  'down',
#  'download',
#  'dramatically',
#  'dried',
#  'driven',
#  'drug',
#  'dsmcpas',
#  'dtt',
#  'duplications',
#  'during',
#  'dusp9',
#  'dysmorphic',
#  'dysplastic',
#  'dystrophic',
#  'e26',
#  'each',
#  'ears',
#  'edta',
#  'effect',
#  'effects',
#  'egta',
#  'either',
#  'electroporation',
#  'elucidation',
#  'elusive',
#  'elute',
#  'eluted',
#  'elution',
#  'embryo',
#  'embryogenesis7',
#  'embryonic',
#  'empty',
#  'encoded',
#  'encodes',
#  'encoding',
#  'endogenous',
#  'endogenously',
#  'enhance',
#  'enhanced',
#  'enriched',
#  'entire',
#  'entity',
#  'epilepsy',
#  'er',
#  'era',
#  'erk',
#  'erk1',
#  'erk2',
#  'erythroblastosis',
#  'erﾎｱ',
#  'escherichia',
#  'especially',
#  'est',
#  'establish',
#  'estrogen',
#  'ets',
#  'ets2',
#  'ets2dbm',
#  'ets2sasa',
#  'ets2wt',
#  'event',
#  'evidence',
#  'exact',
#  'examined',
#  'excess',
#  'exclude',
#  'excluded',
#  'exerted',
#  'exerts',
#  'exhibit',
#  'exhibited',
#  'exist',
#  'existence',
#  'exogenously',
#  'exon',
#  'exons',
#  'expected',
#  'experiment',
#  'experiments',
#  'explained',
#  'explanation',
#  'exploration',
#  'explore',
#  'exploring',
#  'expressed',
#  'expressing',
#  'expression',
#  'extending',
#  'extent',
#  'f7425',
#  'facial',
#  'facilitate',
#  'fact',
#  'factor',
#  'fam58a',
#  'families',
#  'family',
#  'far',
#  'fashion',
#  'fbs',
#  'features',
#  'feet',
#  'feingold',
#  'female',
#  'females',
#  'females12',
#  'femto',
#  'fetal',
#  'fetus',
#  'few',
#  'fide',
#  'fig',
#  'figs',
#  'figure',
#  'films',
#  'final',
#  'finally',
#  'find',
#  'finding',
#  'findings',
#  'fine',
#  'first',
#  'fisher',
#  'five',
#  'flag',
#  'flanking',
#  'fluctuated',
#  'fold',
#  'followed',
#  'following',
#  'for',
#  'form',
#  'formal',
#  'found',
#  'four',
#  'fraction',
#  'frameshift',
#  'frequently',
#  'from',
#  'full',
#  'function',
#  'functional',
#  'functions',
#  'fundamental',
#  'further',
#  'furthermore',
#  'fusion',
#  'gap',
#  'gave',
#  'gel',
#  'genbank',
#  'gene',
#  'general',
#  'generally',
#  'generated',
#  'generic',
#  'genes',
#  'genetic',
#  'genome',
#  'genomic',
#  'genuine',
#  'girls',
#  'give',
#  'glutamax',
#  'glutathione',
#  'glycerol',
#  'glycerophosphate',
#  'goat',
#  'green',
#  'grew',
#  'growth',
#  'gst',
#  'h1',
#  'had',
#  'half',
#  'harboring',
#  'has',
#  'have',
#  'healthy',
#  'heart',
#  'heat',
#  'hek293',
#  'hence',
#  'heparin',
#  'her',
#  'here',
#  'heterodimer',
#  'heterozygous',
#  'high',
#  'higher',
#  'highly',
#  'histone',
#  'home',
#  'homogeneous',
#  'homolog',
#  'homologene',
#  'homologous',
#  'homologs',
#  'homology',
#  'homozygous',
#  'horizontal',
#  'hormone',
#  'how',
#  'however',
#  'hrp',
#  'hs',
#  'human',
#  'hybond',
#  'hybrid',
#  'hybridization',
#  'hypoplastic',
#  'hypothesis',
#  'hypothesized',
#  'hypothetical',
#  'id',
#  'identification',
#  'identified',
#  'identifying',
#  'if',
#  'illustrate',
#  'image',
#  'imidazole',
#  'immediate',
#  'immediately',
#  'immunoprecipitated',
#  'immunoprecipitates',
#  'immunoprecipitation',
#  'immunoprecipitations',
#  'impact',
#  'impeded',
#  'implicated',
#  'implications',
#  'important',
#  'in',
#  'inactivated',
#  'inactivation',
#  'inactivation6',
#  'include',
#  'includes',
#  'including',
#  'incomplete',
#  'incorporated',
#  'increase',
#  'increased',
#  'increases',
#  'increasing',
#  'incubated',
#  'incubation',
#  'indeed',
#  'independent',
#  'independently',
#  'indicate',
#  'indicated',
#  'indicates',
#  'indicative',
#  'individual',
#  'individually',
#  'individuals',
#  'induced',
#  'induces',
#  'inducing',
#  'infected',
#  'infection',
#  'informative',
#  'inhibitor',
#  'inhibits',
#  'insect',
#  'insensitive',
#  'insensitivity',
#  'insertion',
#  'instructions',
#  'intellect',
#  'interact',
#  'interacting',
#  'interaction',
#  'interactor',
#  'interacts',
#  'interesting',
#  'interestingly',
#  'internal',
#  'intringuingly',
#  'intron',
#  'intronless',
#  'investigated',
#  'investigations',
#  'invitrogen',
#  'involved',
#  'involves',
#  'involving',
#  'is',
#  'isoform',
#  'isoforms',
#  'isopropyl',
#  'it',
#  'its',
#  'jetprime',
#  'judged',
#  'kap',
#  'kb',
#  'kd',
#  'key',
#  'kidney',
#  'kinase',
#  'kinases',
#  'knockdown',
#  'knockout',
#  'knowledge',
#  'known',
#  'krt18p48',
#  'labia',
#  'lack',
#  'lacz',
#  'laemli',
#  'lane',
#  'largely',
#  'larger',
#  'last',
#  'latter',
#  'lead',
#  'least',
#  'left',
#  'length',
#  'less',
#  'lesser',
#  'lethal',
#  'level',
#  'levels',
#  'lexa',
#  'lid',
#  'lifespan',
#  'ligase',
#  'ligases',
#  'light',
#  'like',
#  'likely',
#  'line',
#  'link',
#  'linked',
#  'lipofectamine',
#  'lips',
#  'listed',
#  'lists',
#  'literature',
#  'lived',
#  'located',
#  'log2',
#  'longer',
#  'longest',
#  'loss',
#  'losses',
#  'low',
#  'lower',
#  'lymphoblastoid',
#  'lysate',
#  'lysates',
#  'lysed',
#  'lysis',
#  'made',
#  'major',
#  'males',
#  'malformations',
#  'mammalian',
#  'manner',
#  'manufacturers窶',
#  'many',
#  'mapk',
#  'marginally',
#  'marked',
#  'marker',
#  'mass',
#  'materials',
#  'mating',
#  'matrix',
#  'may',
#  'mb',
#  'mcf7',
#  'mechanism',
#  'mechanisms',
#  'mecp2',
#  'mediate',
#  'mediated',
#  'medical',
#  'members',
#  'membranes',
#  'metatarsals',
#  'methods',
#  'methodscloning',
#  'mg132',
#  'mgcl2',
#  'mice',
#  'mice7',
#  'middle',
#  'might',
#  'migration',
#  'mim601446',
#  'min',
#  'missense',
#  'mix',
#  'mixed',
#  'mixture',
#  'ml',
#  'mm',
#  'model',
#  'models',
#  'modulates',
#  'molecular',
#  'monomeric',
#  'mops',
#  'more',
#  'morpholino',
#  'most',
#  'mother',
#  'mother窶電aughter',
#  'motifs',
#  'mouse',
#  'mrna',
#  'mrnas',
#  'much',
#  'multiple',
#  'murine',
#  'must',
#  'mutant',
#  'mutants',
#  'mutated',
#  'mutation',
#  'mutations',
#  'mutations1',
#  'myc',
#  'mycn',
#  'mycn4',
#  'n68xfsx1',
#  'na',
#  'nacl',
#  'naf',
#  'name',
#  'named',
#  'nasal',
#  'ncbi',
#  'negatively',
#  'neighboring',
#  'neon',
#  'nephroblastoma',
#  'new',
#  'next',
#  'nitrocellulose',
#  'nitrophenylphosphate',
#  'nm',
#  'nm_152274',
#  'no',
#  'noncanonical',
#  'noncell',
#  'none',
#  'nonidet',
#  'nonsense',
#  'nonspecific',
#  'nontransfected',
#  'non窶菟roline',
#  'normal',
#  'not',
#  'notably',
#  'note',
#  'noted',
#  'novagen',
#  'novo',
#  'nucleus',
#  'number',
#  'numbers',
#  'observations',
#  'observed',
#  'obtained',
#  'of',
#  'offer',
#  'okihiro',
#  'oligonucleotide',
#  'oligonucleotides',
#  'on',
#  'oncogene',
#  'one',
#  'online',
#  'only',
#  'onto',
#  'or',
#  'origami2',
#  'origin',
#  'originating',
#  'orphan',
#  'other',
#  'others',
#  'other窶冱',
#  'our',
#  'out',
#  'overexpression',
#  'overlap',
#  'overlapping',
#  'overlaps',
#  'owing',
#  'p1',
#  'p2',
#  'p21',
#  'pab0847p',
#  'pab0882',
#  'page',
#  'pair',
#  'pair1',
#  'panel',
#  'paralog',
#  'paralogs',
#  'parental',
#  'parents',
#  'part',
#  'partially',
#  'participate',
#  'particular',
#  'partly',
#  'partner',
#  'partners',
#  'parts',
#  'paternity',
#  'pathogenesis',
#  'pathway',
#  'patient',
#  'patients',
#  'pbs',
#  'pcr',
#  'peg202',
#  'pellet',
#  'pellets',
#  'performed',
#  'ph',
#  'phenocopies',
#  'phenotype',
#  'phenotypes',
#  'phenotypic',
#  'phenylphosphate',
#  'phospho',
#  'phosphodegron',
#  'phosphorylate',
#  'phosphorylated',
#  'phosphorylates',
#  'phosphorylation',
#  'photographs',
#  'photoreceptor',
#  'physical',
#  'picture',
#  'pink',
#  'pivotal',
#  'pjg4',
#  'plasmid',
#  'plasmids',
#  'play',
#  ...]

# %%
# TF-IDF
vectorizer = TfidfVectorizer(min_df=1)
X = vectorizer.fit_transform(texts[0:10])
X.toarray()
# Out:
# array([[ 0.0200171 ,  0.        ,  0.0052518 , ...,  0.01048306,
#          0.01137233,  0.        ],
#        [ 0.00752497,  0.00394912,  0.00691002, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.00752497,  0.00394912,  0.00691002, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.00074773,  0.        ,  0.        , ...,  0.00219291,
#          0.        ,  0.00184644],
#        [ 0.00413625,  0.        ,  0.        , ...,  0.00242612,
#          0.00438654,  0.        ],
#        [ 0.0027102 ,  0.        ,  0.        , ...,  0.00397418,
#          0.00538913,  0.        ]])

# %%
# from nltk.corpus import stopwords
# cachedStopWords = stopwords.words("english")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# d:\users\YB249\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      62             except LookupError as e:
# ---> 63                 try: root = nltk.data.find('corpora/%s' % zip_name)
#      64                 except LookupError: raise e
#
# d:\users\YB249\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/stopwords.zip/stopwords/' not found.  Please
#   use the NLTK Downloader to obtain the resource:  >>>
#   nltk.download()
#   Searched in:
#     - 'd:\\users\\YB249/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'd:\\users\\YB249\\Anaconda3\\nltk_data'
#     - 'd:\\users\\YB249\\Anaconda3\\lib\\nltk_data'
#     - 'd:\\users\\YB249\\AppData\\Roaming\\nltk_data'
# **********************************************************************
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-24-6f5f42ed0704> in <module>()
#       1 from nltk.corpus import stopwords
# ----> 2 cachedStopWords = stopwords.words("english")
#
# d:\users\YB249\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#      97             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#      98
# ---> 99         self.__load()
#     100         # This looks circular, but its not, since __load() changes our
#     101         # __class__ to something new:
#
# d:\users\YB249\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      62             except LookupError as e:
#      63                 try: root = nltk.data.find('corpora/%s' % zip_name)
# ---> 64                 except LookupError: raise e
#      65
#      66         # Load the corpus.
#
# d:\users\YB249\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      59         else:
#      60             try:
# ---> 61                 root = nltk.data.find('corpora/%s' % self.__name)
#      62             except LookupError as e:
#      63                 try: root = nltk.data.find('corpora/%s' % zip_name)
#
# d:\users\YB249\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     639     sep = '*' * 70
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#     643
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/stopwords' not found.  Please use the NLTK
#   Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - 'd:\\users\\YB249/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'd:\\users\\YB249\\Anaconda3\\nltk_data'
#     - 'd:\\users\\YB249\\Anaconda3\\lib\\nltk_data'
#     - 'd:\\users\\YB249\\AppData\\Roaming\\nltk_data'
# **********************************************************************
